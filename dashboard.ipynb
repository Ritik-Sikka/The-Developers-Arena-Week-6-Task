# %%
import plotly.io as pio

pio.renderers.default = "browser"

fig = px.line(
    df,
    x="Month",
    y="Sales",
    color="Category",
    title="Interactive Monthly Sales Trend",
    hover_data=["Profit", "Price"]
)

fig.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="Category", y="Sales", data=df)
plt.title("Sales Distribution by Category")

plt.savefig("visualizations/boxplot.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.violinplot(x="Customer_Type", y="Profit", data=df)
plt.title("Profit Distribution by Customer Type")

plt.savefig("visualizations/violinplot.png", bbox_inches="tight")
plt.show()

# %%
corr = df[['Sales', 'Profit', 'Price']].corr()

plt.figure(figsize=(6,4))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")

plt.savefig("visualizations/heatmap.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(
    x="Category",
    y="Sales",
    data=df,
    estimator=sum
)
plt.title("Total Sales by Category")

plt.savefig("visualizations/barplot.png", bbox_inches="tight")
plt.show()

# %%
fig = px.line(
    df,
    x="Month",
    y="Sales",
    color="Category",
    title="Interactive Monthly Sales Trend",
    hover_data=["Profit", "Price"]
)
fig.show()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\OneDrive\\Desktop\\Interactive-Sales-Dashboard'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'dashboard.ipynb',
#  'dashboard.py',
#  'requirements.txt',
#  'sales_data.csv',
#  'visualizations']

# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df.head()
# Out:
#          Date     Product  Quantity  Price Customer_ID Region  Total_Sales
# 0  2024-01-01       Phone         7  37300     CUST001   East       261100
# 1  2024-01-02  Headphones         4  15406     CUST002  North        61624
# 2  2024-01-03       Phone         2  21746     CUST003   West        43492
# 3  2024-01-04  Headphones         1  30895     CUST004   East        30895
# 4  2024-01-05      Laptop         8  39835     CUST005  North       318680

# %%
# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Create Month column for visualization
df['Month'] = df['Date'].dt.month_name()

df.head()
# Out:
#         Date     Product  Quantity  Price Customer_ID Region  Total_Sales  \
# 0 2024-01-01       Phone         7  37300     CUST001   East       261100
# 1 2024-01-02  Headphones         4  15406     CUST002  North        61624
# 2 2024-01-03       Phone         2  21746     CUST003   West        43492
# 3 2024-01-04  Headphones         1  30895     CUST004   East        30895
# 4 2024-01-05      Laptop         8  39835     CUST005  North       318680
#
#      Month
# 0  January
# 1  January
# 2  January
# 3  January
# 4  January

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

plt.figure(figsize=(6,4))
sns.boxplot(x="Region", y="Total_Sales", data=df)
plt.title("Sales Distribution by Region")

plt.savefig("visualizations/boxplot.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.violinplot(x="Product", y="Quantity", data=df)
plt.title("Quantity Distribution by Product")

plt.savefig("visualizations/violinplot.png", bbox_inches="tight")
plt.show()

# %%
corr = df[['Quantity', 'Price', 'Total_Sales']].corr()

plt.figure(figsize=(6,4))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")

plt.savefig("visualizations/heatmap.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(
    x="Product",
    y="Total_Sales",
    data=df,
    estimator=sum
)
plt.title("Total Sales by Product")

plt.savefig("visualizations/barplot.png", bbox_inches="tight")
plt.show()

# %%
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "browser"

fig = px.line(
    df,
    x="Date",
    y="Total_Sales",
    color="Product",
    title="Interactive Sales Trend by Product",
    hover_data=["Region", "Quantity", "Price"]
)

fig.show()
